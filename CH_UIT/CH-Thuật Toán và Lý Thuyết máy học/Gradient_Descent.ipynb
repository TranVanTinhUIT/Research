# %% [markdown]
# $x^* = \underset{x\in\mathbb{R}}{\arg\min}~x^2$

# %%
import matplotlib.pyplot as plt # library for plotting
import numpy as np # library for vectors, matrices, linear algebra, ....

# %%
# define a function
def f1(x):
    return x**2

# %%
x = np.linspace(-3, 3, 100) # Create a array of 100 equally-spaced numbers from -3 to 3
plt.figure()
plt.plot(x, f1(x))
plt.xlabel('x', fontsize=15)
plt.ylabel('f(x)', fontsize=15)
# Out:
# Text(0, 0.5, 'f(x)')

# %%
def gradient_f1(x):
    return 2.0 * x

# %%
def gradient_descent(f, gradient, x_init, step_size, max_iters=50):
    all = [] # all steps of the algorithm running
    x = x_init
    iter = 0
    while True:
        value = f(x)
        grad = gradient(x)
        print(f'iter:{iter}     x={x:.5f};      f(x)={value:.5f};       f\'(x)={grad:5f}')
        all.append((x, value, grad))  # Saving the result
        x = x - step_size * grad
        iter += 1
        if iter > max_iters:
            break
        if np.fabs(grad) < 1e-5:
            break
    
    return all

# %%
all = gradient_descent(f1, gradient_f1, x_init=-2, step_size=0.1, max_iters=20)
# Out:
# iter:0     x=-2.00000;      f(x)=4.00000;       f'(x)=-4.000000
# iter:1     x=-1.60000;      f(x)=2.56000;       f'(x)=-3.200000
# iter:2     x=-1.28000;      f(x)=1.63840;       f'(x)=-2.560000
# iter:3     x=-1.02400;      f(x)=1.04858;       f'(x)=-2.048000
# iter:4     x=-0.81920;      f(x)=0.67109;       f'(x)=-1.638400
# iter:5     x=-0.65536;      f(x)=0.42950;       f'(x)=-1.310720
# iter:6     x=-0.52429;      f(x)=0.27488;       f'(x)=-1.048576
# iter:7     x=-0.41943;      f(x)=0.17592;       f'(x)=-0.838861
# iter:8     x=-0.33554;      f(x)=0.11259;       f'(x)=-0.671089
# iter:9     x=-0.26844;      f(x)=0.07206;       f'(x)=-0.536871
# iter:10     x=-0.21475;      f(x)=0.04612;       f'(x)=-0.429497
# iter:11     x=-0.17180;      f(x)=0.02951;       f'(x)=-0.343597
# iter:12     x=-0.13744;      f(x)=0.01889;       f'(x)=-0.274878
# iter:13     x=-0.10995;      f(x)=0.01209;       f'(x)=-0.219902
# iter:14     x=-0.08796;      f(x)=0.00774;       f'(x)=-0.175922
# iter:15     x=-0.07037;      f(x)=0.00495;       f'(x)=-0.140737
# iter:16     x=-0.05629;      f(x)=0.00317;       f'(x)=-0.112590
# iter:17     x=-0.04504;      f(x)=0.00203;       f'(x)=-0.090072
# iter:18     x=-0.03603;      f(x)=0.00130;       f'(x)=-0.072058
# iter:19     x=-0.02882;      f(x)=0.00083;       f'(x)=-0.057646
# iter:20     x=-0.02306;      f(x)=0.00053;       f'(x)=-0.046117

# %%
import time
from IPython import display

# %%
x = np.linspace(-3, 3, 100) # Create a array of 100 equally-spaced numbers from -3 to 3

for iteration in range(0, len(all)):
    plt.figure()
    ax = plt.gca()
    ax.set_aspect(0.5) # ratio of height to width ?
    plt.plot(x, f1(x))
    plt.xlabel('x', fontsize=15)
    plt.ylabel('f(x)', fontsize=15)
    plt.xlim(-3,3)
    plt.ylim(-0.5,9)

    plt.scatter(all[iteration][0], all[iteration][1], c='red', s=50)
    plt.show()
    time.sleep(1)
    if iteration < len(all):
        display.clear_output(wait=True)

# %% [markdown]
# $x^*=\underset{x\in\mathbb{R}}{\arg\min}~x^4+2.5x^3-0.5x^2-x+1$

# %%
def f2(x):
    return x**4 + 2.5*x**3 - 0.5*x**2 - x + 1.0

# %%
x = np.linspace(-3, 3, 100) # Create a array of 100 equally-spaced numbers from -3 to 3
plt.figure()
ax = plt.gca()
ax.set_aspect(0.5) # ratio of height to width ?
plt.plot(x, f2(x))
plt.xlabel('x', fontsize=15)
plt.ylabel('f(x)', fontsize=15)
plt.xlim(-4,2)
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %%
def gradient_f2(x):
    return 4.0*x**3 + 3.0*2.5*x**2 - x - 1.0

# %%
def gradient_descent(f, gradient, x_init, step_size, max_iters=50):
    all = [] # all steps of the algorithm running
    x = x_init
    iter = 0
    while True:
        value = f(x)
        grad = gradient(x)
        print(f'iter:{iter}     x={x:.5f};      f(x)={value:.5f};       f\'(x)={grad:5f}')
        all.append((x, value, grad))  # Saving the result
        x = x - step_size * grad
        iter += 1
        if iter > max_iters:
            break
        if np.fabs(grad) < 1e-5:
            break
    
    return all

# %%
all = gradient_descent(f2, gradient_f2, x_init=0.9, step_size=0.03, max_iters=50)
# Out:
# iter:0     x=0.90000;      f(x)=2.17360;       f'(x)=7.091000
# iter:1     x=0.68727;      f(x)=1.11123;       f'(x)=3.153781
# iter:2     x=0.59266;      f(x)=0.87551;       f'(x)=1.874320
# iter:3     x=0.53643;      f(x)=0.78840;       f'(x)=1.239163
# iter:4     x=0.49925;      f(x)=0.74935;       f'(x)=0.867902
# iter:5     x=0.47322;      f(x)=0.72988;       f'(x)=0.630151
# iter:6     x=0.45431;      f(x)=0.71951;       f'(x)=0.468750
# iter:7     x=0.44025;      f(x)=0.71373;       f'(x)=0.354702
# iter:8     x=0.42961;      f(x)=0.71040;       f'(x)=0.271766
# iter:9     x=0.42145;      f(x)=0.70843;       f'(x)=0.210162
# iter:10     x=0.41515;      f(x)=0.70726;       f'(x)=0.163668
# iter:11     x=0.41024;      f(x)=0.70654;       f'(x)=0.128148
# iter:12     x=0.40639;      f(x)=0.70610;       f'(x)=0.100755
# iter:13     x=0.40337;      f(x)=0.70583;       f'(x)=0.079474
# iter:14     x=0.40099;      f(x)=0.70566;       f'(x)=0.062847
# iter:15     x=0.39910;      f(x)=0.70555;       f'(x)=0.049798
# iter:16     x=0.39761;      f(x)=0.70549;       f'(x)=0.039520
# iter:17     x=0.39642;      f(x)=0.70544;       f'(x)=0.031403
# iter:18     x=0.39548;      f(x)=0.70542;       f'(x)=0.024977
# iter:19     x=0.39473;      f(x)=0.70540;       f'(x)=0.019882
# iter:20     x=0.39413;      f(x)=0.70539;       f'(x)=0.015836
# iter:21     x=0.39366;      f(x)=0.70538;       f'(x)=0.012619
# iter:22     x=0.39328;      f(x)=0.70538;       f'(x)=0.010060
# iter:23     x=0.39298;      f(x)=0.70538;       f'(x)=0.008023
# iter:24     x=0.39274;      f(x)=0.70537;       f'(x)=0.006399
# iter:25     x=0.39255;      f(x)=0.70537;       f'(x)=0.005105
# iter:26     x=0.39239;      f(x)=0.70537;       f'(x)=0.004074
# iter:27     x=0.39227;      f(x)=0.70537;       f'(x)=0.003251
# iter:28     x=0.39217;      f(x)=0.70537;       f'(x)=0.002595
# iter:29     x=0.39210;      f(x)=0.70537;       f'(x)=0.002071
# iter:30     x=0.39203;      f(x)=0.70537;       f'(x)=0.001653
# iter:31     x=0.39198;      f(x)=0.70537;       f'(x)=0.001320
# iter:32     x=0.39194;      f(x)=0.70537;       f'(x)=0.001054
# iter:33     x=0.39191;      f(x)=0.70537;       f'(x)=0.000841
# iter:34     x=0.39189;      f(x)=0.70537;       f'(x)=0.000671
# iter:35     x=0.39187;      f(x)=0.70537;       f'(x)=0.000536
# iter:36     x=0.39185;      f(x)=0.70537;       f'(x)=0.000428
# iter:37     x=0.39184;      f(x)=0.70537;       f'(x)=0.000342
# iter:38     x=0.39183;      f(x)=0.70537;       f'(x)=0.000273
# iter:39     x=0.39182;      f(x)=0.70537;       f'(x)=0.000218
# iter:40     x=0.39181;      f(x)=0.70537;       f'(x)=0.000174
# iter:41     x=0.39181;      f(x)=0.70537;       f'(x)=0.000139
# iter:42     x=0.39180;      f(x)=0.70537;       f'(x)=0.000111
# iter:43     x=0.39180;      f(x)=0.70537;       f'(x)=0.000089
# iter:44     x=0.39180;      f(x)=0.70537;       f'(x)=0.000071
# iter:45     x=0.39180;      f(x)=0.70537;       f'(x)=0.000056
# iter:46     x=0.39179;      f(x)=0.70537;       f'(x)=0.000045
# iter:47     x=0.39179;      f(x)=0.70537;       f'(x)=0.000036
# iter:48     x=0.39179;      f(x)=0.70537;       f'(x)=0.000029
# iter:49     x=0.39179;      f(x)=0.70537;       f'(x)=0.000023
# iter:50     x=0.39179;      f(x)=0.70537;       f'(x)=0.000018

# %%
import time
from IPython import display

# %%
x = np.linspace(-3, 3, 100) # Create a array of 100 equally-spaced numbers from -3 to 3

for iteration in range(0, len(all)):
    plt.figure()
    ax = plt.gca()
    ax.set_aspect(0.5) # ratio of height to width ?
    plt.plot(x, f2(x))
    plt.xlabel('x', fontsize=15)
    plt.ylabel('f(x)', fontsize=15)
    plt.xlim(-4,2)
    plt.ylim(-4,4)

    plt.scatter(all[iteration][0], all[iteration][1], c='red', s=50)
    plt.show()
    time.sleep(0.1)
    if iteration < len(all):
        display.clear_output(wait=True)

# %%
def Ackley(x,y):
    return -20.0 * np.exp(-0.2 * np.sqrt(0.5 * (x**2 + y**2))) - np.exp(0.5 * (np.cos(2 * np.pi * x) + np.cos(2 * np.pi * y))) + np.e + 20

# %%
x = np.linspace(-3,3, 100)
y = np.linspace(-3,3, 100)
X, Y= np.meshgrid(x,y)
Z = Ackley(X, Y)
plt.figure(figsize=(12,6))
ax1 = plt.subplot(1,2,1, projection='3d')
surf = ax1.plot_surface(X,Y,Z, cmap='jet', alpha=0.7)
ax2 = plt.subplot(1,2,2)
contour = ax2.contourf(X,Y,Z, levels=50, cmap='jet', alpha=0.7)
